# %%
import pandas as pd
df_train = pd.read_json('train.json')

# %%
df_train.head()
# Out:
#        cuisine     id                                        ingredients
# 0        greek  10259  [romaine lettuce, black olives, grape tomatoes...
# 1  southern_us  25693  [plain flour, ground pepper, salt, tomatoes, g...
# 2     filipino  20130  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3       indian  22213                [water, vegetable oil, wheat, salt]
# 4       indian  13162  [black pepper, shallots, cornflour, cayenne pe...

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
df_train['cuisine'].value_counts().plot(kind='bar')

# %%
df_train.describe()
# Out:
#                  id
# count  39774.000000
# mean   24849.536959
# std    14360.035505
# min        0.000000
# 25%    12398.250000
# 50%    24887.000000
# 75%    37328.500000
# max    49717.000000

# %%
df_train.query('cuisine == 'chinese'')
# Out:
#   File "<ipython-input-10-f7159dc6cdd9>", line 1
#     df_train.query('cuisine == 'chinese'')
#                                       ^
# SyntaxError: invalid syntax

# %%
df_train['all_ingredients'] = df_train['ingredients'].map(";".join)

# %%
df_train.head()
# Out:
#        cuisine     id                                        ingredients  \
# 0        greek  10259  [romaine lettuce, black olives, grape tomatoes...
# 1  southern_us  25693  [plain flour, ground pepper, salt, tomatoes, g...
# 2     filipino  20130  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3       indian  22213                [water, vegetable oil, wheat, salt]
# 4       indian  13162  [black pepper, shallots, cornflour, cayenne pe...
#
#                                      all_ingredients
# 0  romaine lettuce;black olives;grape tomatoes;ga...
# 1  plain flour;ground pepper;salt;tomatoes;ground...
# 2  eggs;pepper;salt;mayonaise;cooking oil;green c...
# 3                     water;vegetable oil;wheat;salt
# 4  black pepper;shallots;cornflour;cayenne pepper...

# %%
\],
                                                 title='garlic cloves as found per cuisine')

# %%
relative_freq = (df_train[indices]['cuisine'].value_counts() / df_train['cuisine'].value_counts())
relative_freq.sort(inplace=True)
relative_freq.plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-94fc8f4a88c5> in <module>()
#       1 relative_freq = (df_train[indices]['cuisine'].value_counts() / df_train['cuisine'].value_counts())
# ----> 2 relative_freq.sort(inplace=True)
#       3 relative_freq.plot(kind='bar')
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'sort'

# %%
print(indices)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12        True
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 39744     True
# 39745    False
# 39746    False
# 39747    False
# 39748    False
# 39749    False
# 39750    False
# 39751    False
# 39752    False
# 39753     True
# 39754     True
# 39755    False
# 39756    False
# 39757     True
# 39758    False
# 39759    False
# 39760    False
# 39761     True
# 39762    False
# 39763    False
# 39764    False
# 39765    False
# 39766    False
# 39767    False
# 39768    False
# 39769    False
# 39770    False
# ...

# %%
type(indices)
# Out:
# pandas.core.series.Series

# %%
import pandas

# %%
relative_freq = (df_train[indices]['cuisine'].value_counts() / df_train['cuisine'].value_counts())
relative_freq.sort_values(inplace = True)
relative_freq.plot(kind='bar')

# %%
print(df_train['cuisine'].value_counts())
# Out:
# italian         7838
# mexican         6438
# southern_us     4320
# indian          3003
# chinese         2673
# french          2646
# cajun_creole    1546
# thai            1539
# japanese        1423
# greek           1175
# spanish          989
# korean           830
# vietnamese       825
# moroccan         821
# british          804
# filipino         755
# irish            667
# jamaican         526
# russian          489
# brazilian        467
# Name: cuisine, dtype: int64

# %%
type(df_train['all_ingredients'])
# Out:
# pandas.core.series.Series

# %%
df_train.head()
# Out:
#        cuisine     id                                        ingredients  \
# 0        greek  10259  [romaine lettuce, black olives, grape tomatoes...
# 1  southern_us  25693  [plain flour, ground pepper, salt, tomatoes, g...
# 2     filipino  20130  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3       indian  22213                [water, vegetable oil, wheat, salt]
# 4       indian  13162  [black pepper, shallots, cornflour, cayenne pe...
#
#                                      all_ingredients
# 0  romaine lettuce;black olives;grape tomatoes;ga...
# 1  plain flour;ground pepper;salt;tomatoes;ground...
# 2  eggs;pepper;salt;mayonaise;cooking oil;green c...
# 3                     water;vegetable oil;wheat;salt
# 4  black pepper;shallots;cornflour;cayenne pepper...

# %%
from collections import Counter

counters = {}
for cuisine in df_train['cuisine'].unique():
    counters[cuisine] = Counter()
    indices = (df_train['cuisine'] == cuisine)
    for ingredients in df_train[indices]['ingredients']:
        counters[cuisine].update(ingredients)

# %%
for cuisine in df_train['cuisine'].unique():
    reversed(counters[cuisine].least_common(10))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-55-25bc88117de8> in <module>()
#       1 for cuisine in df_train['cuisine'].unique():
# ----> 2     reversed(counters[cuisine].least_common(10))
#
# AttributeError: 'Counter' object has no attribute 'least_common'

# %%
print(counters)
# Out:
# {'greek': Counter({'salt': 572, 'olive oil': 504, 'dried oregano': 267, 'garlic cloves': 254, 'feta cheese crumbles': 252, 'extra-virgin olive oil': 229, 'fresh lemon juice': 222, 'ground black pepper': 221, 'garlic': 216, 'pepper': 203, 'feta cheese': 191, 'cucumber': 187, 'purple onion': 186, 'onions': 185, 'lemon juice': 183, 'tomatoes': 156, 'water': 143, 'lemon': 129, 'fresh parsley': 113, 'fresh dill': 108, 'all-purpose flour': 100, 'red wine vinegar': 99, 'butter': 90, 'black pepper': 89, 'kosher salt': 85, 'greek yogurt': 84, 'fresh oregano': 83, 'eggs': 80, 'kalamata': 78, 'sugar': 77, 'ground cinnamon': 73, 'large eggs': 72, 'pitted kalamata olives': 70, 'minced garlic': 68, 'chopped fresh mint': 68, 'ground lamb': 68, 'honey': 67, 'cooking spray': 67, 'flat leaf parsley': 65, 'eggplant': 61, 'unsalted butter': 59, 'diced tomatoes': 57, 'plain yogurt': 56, 'green onions': 55, 'cherry tomatoes': 51, 'red bell pepper': 48, 'greek style plain yogurt': 48, 'zucchini': 47, 'plum
# ...

# %%
df = df_train.head(6)

# %%
from collections import Counter

counters = {}
for cuisine in df['cuisine'].unique():
    counters[cuisine] = Counter()
    indices = (df['cuisine'] == cuisine)
    for ingredients in df[indices]['ingredients']:
        counters[cuisine].update(ingredients)

# %%
counters
# Out:
# {'filipino': Counter({'butter': 1,
#           'chicken livers': 1,
#           'cooking oil': 1,
#           'eggs': 1,
#           'garlic powder': 1,
#           'green chilies': 1,
#           'grilled chicken breasts': 1,
#           'mayonaise': 1,
#           'pepper': 1,
#           'salt': 1,
#           'soy sauce': 1,
#           'yellow onion': 1}),
#  'greek': Counter({'black olives': 1,
#           'feta cheese crumbles': 1,
#           'garbanzo beans': 1,
#           'garlic': 1,
#           'grape tomatoes': 1,
#           'pepper': 1,
#           'purple onion': 1,
#           'romaine lettuce': 1,
#           'seasoning': 1}),
#  'indian': Counter({'bay leaf': 1,
#           'black pepper': 1,
#           'boneless chicken skinless thigh': 1,
#           'butter': 1,
#           'cayenne pepper': 1,
#           'chili powder': 1,
#           'cornflour': 1,
#           'double cream': 1,
#           'garam masala': 1,
#           'garlic paste': 1,
# ...

# %%
(sorted(counters['indian'].items(),key = lambda pair: pair[1]))
# Out:
# [('vegetable oil', 1),
#  ('wheat', 1),
#  ('black pepper', 1),
#  ('shallots', 1),
#  ('cornflour', 1),
#  ('cayenne pepper', 1),
#  ('onions', 1),
#  ('garlic paste', 1),
#  ('milk', 1),
#  ('butter', 1),
#  ('lemon juice', 1),
#  ('chili powder', 1),
#  ('passata', 1),
#  ('oil', 1),
#  ('ground cumin', 1),
#  ('boneless chicken skinless thigh', 1),
#  ('garam masala', 1),
#  ('double cream', 1),
#  ('natural yogurt', 1),
#  ('bay leaf', 1),
#  ('water', 2),
#  ('salt', 2)]

# %%
sorted(counters['indian'].items(),key = lambda pair: pair[1])[0:6]
# Out:
# [('vegetable oil', 1),
#  ('wheat', 1),
#  ('black pepper', 1),
#  ('shallots', 1),
#  ('cornflour', 1),
#  ('cayenne pepper', 1)]

# %%
from collections import Counter

counters = {}
for cuisine in df_train['cuisine'].unique():
    counters[cuisine] = Counter()
    indices = (df_train['cuisine'] == cuisine)
    for ingredients in df_train[indices]['ingredients']:
        counters[cuisine].update(ingredients)

# %%
for cuisine in df_train['cuisine'].unique():
    l = {}
    l = (sorted(counters[cuisine].items(),key = lambda pair: pair[1]))[0:10]
    print(l)
# Out:
# [('caul fat', 1), ('boneless chop pork', 1), ('calimyrna figs', 1), ('octopuses', 1), ('vanilla lowfat yogurt', 1), ('fat skimmed chicken broth', 1), ('brown rice', 1), ('flour for dusting', 1), ('skinless chicken thighs', 1), ('pitted prunes', 1)]
# [('sirloin tip roast', 1), ('condensed cheddar cheese soup', 1), ('instant butterscotch pudding mix', 1), ('frozen edamame beans', 1), ('luke warm water', 1), ('pecan pie', 1), ('haricots verts', 1), ('wax beans', 1), ('dried kidney beans', 1), ('vegetable juice', 1)]
# [('grilled chicken breasts', 1), ('mushroom powder', 1), ('fresh bay leaves', 1), ('adobo sauce', 1), ('taco seasoning', 1), ('pork loin chops', 1), ('chipotle peppers', 1), ('blueberri preserv', 1), ('basil', 1), ('filet', 1)]
# [('burger buns', 1), ('ground flaxseed', 1), ('ramps', 1), ('pearl barley', 1), ('diced bell pepper', 1), ('cauliflower flowerets', 1), ('roasted salted cashews', 1), ('catfish', 1), ('dried minced onion', 1), ('beef stew', 1)]
# ...

# %%
df_train['cuisine'].corr(df_train['cuisine'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-97-5bfeddfca045> in <module>()
# ----> 1 df_train['cuisine'].corr(df_train['cuisine'])
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in corr(self, other, method, min_periods)
#    1373             return np.nan
#    1374         return nanops.nancorr(this.values, other.values, method=method,
# -> 1375                               min_periods=min_periods)
#    1376
#    1377     def cov(self, other, min_periods=None):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      60             try:
#      61                 with np.errstate(invalid='ignore'):
# ---> 62                     return f(*args, **kwargs)
#      63             except ValueError as e:
#      64                 # we want to transform an object array
#
# ...

# %%
import pandas as pd

# %%
df_dummy = pd.read_csv('result.csv')

# %%
df_dummy.columns
# Out:
# Index(['[' '', '[u'chinese'', '[u'moroccan'', '[u'british'', '[u'greek'',
#        '[u'russian'', '[u'southern_us'', '[u'irish'', '[u'mexican'',
#        '[u'vietnamese'', '[u'brazilian'', '[u'japanese'', '[u'indian'',
#        '[u'jamaican'', '[u'french'', '[u'spanish'', '[u'cajun_creole'',
#        '[u'thai'', '[u'korean'', '[u'filipino'', '[u'italian'', 'Max'],
#       dtype='object')

# %%
def strip_non_ascii(string):
    ''' Returns the string without non ASCII characters'''
    string = string[3:len(string)-1] #(c for c in string if 0 < ord(c) < 127)
    return string

# %%
df_dummy.columns = [strip_non_ascii(x) for x in df_dummy.columns]

# %%
print(df_dummy.columns)
# Out:
# Index(['', 'chinese', 'moroccan', 'british', 'greek', 'russian', 'southern_us',
#        'irish', 'mexican', 'vietnamese', 'brazilian', 'japanese', 'indian',
#        'jamaican', 'french', 'spanish', 'cajun_creole', 'thai', 'korean',
#        'filipino', 'italian', ''],
#       dtype='object')

# %%
df_dummy['chinese'].corr(df_dummy['moroccan'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-130-6a732f3d45ab> in <module>()
# ----> 1 df_dummy['chinese'].corr(df_dummy['moroccan'])
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in corr(self, other, method, min_periods)
#    1373             return np.nan
#    1374         return nanops.nancorr(this.values, other.values, method=method,
# -> 1375                               min_periods=min_periods)
#    1376
#    1377     def cov(self, other, min_periods=None):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      60             try:
#      61                 with np.errstate(invalid='ignore'):
# ---> 62                     return f(*args, **kwargs)
#      63             except ValueError as e:
#      64                 # we want to transform an object array
#
# ...
